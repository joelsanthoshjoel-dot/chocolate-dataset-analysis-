# %%
import pandas as pd

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\joels\Downloads\archive (13)\products.csv")
df.isnull()
df.dropna
df.head(10)
# Out:
#   product_id           product_name    brand category  cocoa_percent  weight_g
# 0      P0001    White Chocolate 80%     Mars  Truffle             80       120
# 1      P0002     Dark Chocolate 70%  Cadbury  Praline             70       100
# 2      P0003  Truffle Chocolate 70%  Hershey  Praline             70       120
# 3      P0004     Milk Chocolate 50%     Mars  Praline             50        80
# 4      P0005    White Chocolate 70%  Ferrero    White             70        50
# 5      P0006     Milk Chocolate 50%  Hershey     Dark             50        50
# 6      P0007  Praline Chocolate 70%  Cadbury  Praline             70       120
# 7      P0008    White Chocolate 90%   Godiva     Dark             90       100
# 8      P0009    White Chocolate 50%  Ferrero     Dark             50        80
# 9      P0010     Milk Chocolate 70%  Hershey  Truffle             70        50

# %%
df["brand"].value_counts().head(20)
# Out:
# brand
# Cadbury    37
# Ferrero    37
# Lindt      35
# Mars       33
# Godiva     30
# Hershey    28
# Name: count, dtype: int64

# %%
df["product_name"].value_counts().head(20)
# Out:
# product_name
# Dark Chocolate 50%       14
# Truffle Chocolate 80%    13
# Praline Chocolate 50%    11
# Milk Chocolate 70%       11
# White Chocolate 50%      10
# Dark Chocolate 60%       10
# Truffle Chocolate 90%     9
# White Chocolate 80%       9
# White Chocolate 90%       9
# Praline Chocolate 70%     9
# Truffle Chocolate 50%     8
# Dark Chocolate 70%        8
# Dark Chocolate 90%        8
# White Chocolate 70%       8
# Milk Chocolate 50%        8
# Milk Chocolate 60%        7
# Praline Chocolate 90%     7
# Truffle Chocolate 70%     7
# White Chocolate 60%       6
# Milk Chocolate 80%        6
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        cocoa_percent    weight_g
# count     200.000000  200.000000
# mean       69.150000  107.500000
# std        14.623499   50.898954
# min        50.000000   50.000000
# 25%        50.000000   80.000000
# 50%        70.000000  100.000000
# 75%        80.000000  120.000000
# max        90.000000  200.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of     product_id           product_name    brand category  cocoa_percent  \
# 0        P0001    White Chocolate 80%     Mars  Truffle             80
# 1        P0002     Dark Chocolate 70%  Cadbury  Praline             70
# 2        P0003  Truffle Chocolate 70%  Hershey  Praline             70
# 3        P0004     Milk Chocolate 50%     Mars  Praline             50
# 4        P0005    White Chocolate 70%  Ferrero    White             70
# ..         ...                    ...      ...      ...            ...
# 195      P0196    White Chocolate 60%     Mars  Praline             60
# 196      P0197  Truffle Chocolate 90%  Hershey  Truffle             90
# 197      P0198     Dark Chocolate 90%  Ferrero    White             90
# 198      P0199     Dark Chocolate 70%  Hershey    White             70
# 199      P0200     Milk Chocolate 50%  Cadbury     Milk             50
#
#      weight_g
# 0         120
# 1         100
# 2         120
# 3          80
# ...

# %%
df.shape
# Out:
# (200, 6)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(df['category'].head(10), df['cocoa_percent'].head(10))
plt.xticks(rotation=45)
plt.title("category vs cocoa percentage")
plt.show()

# %% [markdown]
# workflow
# import the chocolate data set into pandas using read code to load the data set use methods like head,info,shape to understand the structure of the dataset.
# clean the data which i loaded to avoid missing values,duplicates,or null coloums in the dataset by useing dropna,drop duplicates,isnull.
# summerize the dataset by use describe code to generate statistical summerize like mean,median,min,max,standard deviation,etc.and value counts to count product count and brand.
# visualize data to create plot by using matplotlib in pandas and secborn to create a visual charts by using bar chart,hists chart,scatterchart.

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\joels\Downloads\archive (13)\sales.csv")
df.dropna()
df.isnull()
df.head(10)
# Out:
#       order_id  order_date product_id store_id customer_id  quantity  \
# 0  0RD00000001  2023-01-07      P0080     S093     C040749         5
# 1  0RD00000002  2023-10-22      P0173     S065     C020161         3
# 2  0RD00000003  2023-05-07      P0115     S078     C048069         2
# 3  0RD00000004  2024-06-23      P0186     S088     C047901         2
# 4  0RD00000005  2024-09-24      P0197     S054     C033950         1
# 5  0RD00000006  2024-03-29      P0160     S089     C008918         4
# 6  0RD00000007  2023-02-26      P0062     S024     C002897         1
# 7  0RD00000008  2023-11-03      P0111     S085     C038072         5
# 8  0RD00000009  2024-10-11      P0135     S029     C003786         4
# 9  0RD00000010  2023-12-17      P0069     S056     C043148         3
#
#    unit_price  discount  revenue   cost  profit
# 0       14.43      0.15    61.33  42.77   18.56
# 1       12.01      0.00    36.03  19.06   16.97
# 2       10.02      0.00    20.04  10.29    9.75
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            order_id  order_date product_id store_id customer_id  quantity  \
# 0       0RD00000001  2023-01-07      P0080     S093     C040749         5
# 1       0RD00000002  2023-10-22      P0173     S065     C020161         3
# 2       0RD00000003  2023-05-07      P0115     S078     C048069         2
# 3       0RD00000004  2024-06-23      P0186     S088     C047901         2
# 4       0RD00000005  2024-09-24      P0197     S054     C033950         1
# ...             ...         ...        ...      ...         ...       ...
# 999995  0RD00999996  2023-04-15      P0103     S053     C044763         4
# 999996  0RD00999997  2023-05-26      P0094     S058     C004441         2
# 999997  0RD00999998  2023-07-05      P0097     S041     C044879         3
# 999998  0RD00999999  2024-01-03      P0090     S083     C042525         1
# 999999  0RD01000000  2024-04-10      P0175     S090     C025078         1
#
# ...

# %%
df.shape
# Out:
# (1000000, 11)

# %%
df.head(10)
# Out:
#       order_id  order_date product_id store_id customer_id  quantity  \
# 0  0RD00000001  2023-01-07      P0080     S093     C040749         5
# 1  0RD00000002  2023-10-22      P0173     S065     C020161         3
# 2  0RD00000003  2023-05-07      P0115     S078     C048069         2
# 3  0RD00000004  2024-06-23      P0186     S088     C047901         2
# 4  0RD00000005  2024-09-24      P0197     S054     C033950         1
# 5  0RD00000006  2024-03-29      P0160     S089     C008918         4
# 6  0RD00000007  2023-02-26      P0062     S024     C002897         1
# 7  0RD00000008  2023-11-03      P0111     S085     C038072         5
# 8  0RD00000009  2024-10-11      P0135     S029     C003786         4
# 9  0RD00000010  2023-12-17      P0069     S056     C043148         3
#
#    unit_price  discount  revenue   cost  profit
# 0       14.43      0.15    61.33  42.77   18.56
# 1       12.01      0.00    36.03  19.06   16.97
# 2       10.02      0.00    20.04  10.29    9.75
# ...

# %%
df.describe()
# Out:
#              quantity      unit_price        discount         revenue  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         2.999589        9.002449        0.056248       25.486129
# std          1.413621        3.462902        0.076809       16.367864
# min          1.000000        3.000000        0.000000        2.400000
# 25%          2.000000        6.000000        0.000000       12.160000
# 50%          3.000000        9.010000        0.000000       21.920000
# 75%          4.000000       12.000000        0.150000       35.880000
# max          5.000000       15.000000        0.200000       75.000000
#
#                  cost          profit
# count  1000000.000000  1000000.000000
# mean        15.291554       10.194565
# std          9.972706        6.778760
# min          1.200000        0.730000
# 25%          7.240000        4.780000
# 50%         13.030000        8.600000
# 75%         21.410000       14.170000
# ...

# %%
df["cost"].value_counts().head(10)
# Out:
# cost
# 7.12    621
# 6.14    621
# 6.68    621
# 6.72    616
# 7.08    614
# 6.54    610
# 6.55    610
# 6.89    609
# 7.20    609
# 7.19    608
# Name: count, dtype: int64

# %%
df["discount"].sum()
# Out:
# np.float64(56247.850000000006)

# %%
df["revenue"].median()
# Out:
# 21.92

# %%
df["revenue"].value_counts().head(20)
# Out:
# revenue
# 12.24    638
# 21.60    636
# 14.28    633
# 19.80    626
# 12.72    609
# 14.04    604
# 14.40    604
# 19.20    598
# 14.88    591
# 12.60    591
# 20.40    588
# 12.48    584
# 24.00    582
# 18.00    578
# 27.00    578
# 28.80    576
# 14.76    576
# 16.20    559
# 13.68    559
# 16.80    557
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(df['profit'].head(10),df['revenue'].head(10))
plt.xticks(rotation=45)
plt.xlabel("profit")
plt.title("profit vs revenue")
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(
    df[
        ['revenue',
         'order_date']
    ]
)

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    x='revenue',
    y='profit',
    data=df
)

plt.show()
